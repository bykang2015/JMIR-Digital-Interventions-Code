# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'positive_ucla_changes' and 'negative_ucla_changes' are lists of individual change scores for UCLA Loneliness
# Assuming 'positive_phq9_changes' and 'negative_phq9_changes' are lists of individual change scores for PHQ-9

positive_ucla_changes = [-2, -5, 3, 3, -6, -3, -8, -10, -7, 4, -6, 4, -4, -8, ]

negative_ucla_changes = [1, -8, -4, -10, 2, -3, 2, -9, -3, -3, -3, -3, -3,-3 ]

positive_phq9_changes = [0, -3, -3, -2, 0, -2, -4, -3, -2, -4, -3, -3, -5, -4 ]

negative_phq9_changes = [-4, -6, 0, 8, 2, -6, -8, -10, -3, -3, -3, -3, -3, -3]
# Generating indices for plotting
indices_positive = np.arange(len(positive_ucla_changes))
indices_negative = np.arange(len(negative_ucla_changes))

# Plotting bar graphs with patterns and different shades of grey for UCLA Loneliness
plt.figure(figsize=(12, 6))
bar_width = 0.35
plt.bar(
    indices_positive - bar_width / 2,
    positive_ucla_changes,
    bar_width,
    color='lightgrey',  # Light grey for positive group
    label='Positive Group (UCLA)',
)
plt.bar(
    indices_negative + bar_width / 2,
    negative_ucla_changes,
    bar_width,
    hatch='////',  # Denser pattern for negative group
    color='darkgrey',  # Dark grey for negative group
    label='Negative Group (UCLA)',
)

# Plotting bar graphs with patterns and different shades of grey for PHQ-9
plt.bar(
    indices_positive - bar_width / 2,
    positive_phq9_changes,
    bar_width,
    color='grey',  # Grey for positive group
    alpha=0.7,  # Adjust alpha for transparency
    label='Positive Group (PHQ-9)',
)
plt.bar(
    indices_negative + bar_width / 2,
    negative_phq9_changes,
    bar_width,
    hatch='////',  # Denser pattern for negative group
    color='black',  # Black for negative group
    alpha=0.7,  # Adjust alpha for transparency
    label='Negative Group (PHQ-9)',
)

plt.xlabel('Participant')
plt.ylabel('Change in Score')
plt.title('Change in Score: Perceived Benefits of Action_Positive vs. Negative Group')
plt.legend()
plt.xticks(np.arange(0, max(len(positive_ucla_changes), len(negative_ucla_changes))))
plt.show()

# %%
from scipy.stats import mannwhitneyu

# Assuming 'positive_ucla_changes' and 'negative_ucla_changes' are lists of individual change scores for UCLA Loneliness
# Assuming 'positive_phq9_changes' and 'negative_phq9_changes' are lists of individual change scores for PHQ-9

positive_ucla_changes = [-2, -5, 3, 3, -6, -3, -8, -10, -7, 4, -6, 4, -4, -8]
negative_ucla_changes = [1, -8, -4, -10, 2, -3, 2, -9, -3, -3, -3, -3, -3, -3]
positive_phq9_changes = [0, -3, -3, -2, 0, -2, -4, -3, -2, -4, -3, -3, -5, -4]
negative_phq9_changes = [-4, -6, 0, 8, 2, -6, -8, -10, -3, -3, -3, -3, -3, -3]

# Mann-Whitney U Test for UCLA Loneliness changes
ucla_stat, ucla_p_value = mannwhitneyu(positive_ucla_changes, negative_ucla_changes)
print(f'UCLA Loneliness Mann-Whitney U Test p-value: {ucla_p_value}')

# Mann-Whitney U Test for PHQ-9 changes
phq9_stat, phq9_p_value = mannwhitneyu(positive_phq9_changes, negative_phq9_changes)
print(f'PHQ-9 Mann-Whitney U Test p-value: {phq9_p_value}')
# Out:
# UCLA Loneliness Mann-Whitney U Test p-value: 0.9258235766197799
# PHQ-9 Mann-Whitney U Test p-value: 0.47589224885778136

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'positive_ucla_changes' and 'negative_ucla_changes' are lists of individual change scores for UCLA Loneliness
# Assuming 'positive_phq9_changes' and 'negative_phq9_changes' are lists of individual change scores for PHQ-9
# Assuming 'positive_ucla_changes' and 'negative_ucla_changes' are lists of individual change scores for UCLA Loneliness
positive_ucla_changes = [-2, -10, 8, 5, -7, 4, -17, -5, 3, 3, -6, 4, -6, 4, -4, -8, -13, -3, -8]
negative_ucla_changes = [-4, 1, -3, -10, 2, -8, 2, -9]

# Assuming 'positive_phq9_changes' and 'negative_phq9_changes' are lists of individual change scores for PHQ-9
positive_phq9_changes = [-10, 2, 4, -2, -4, -3, -2, 0, -3, -3, -2, -4, -3, -3, -5, -4, -8, 0, 1]
negative_phq9_changes = [0, -4, -6, 8, 2, -6, -8, -10]

# Generating indices for plotting
indices_positive = np.arange(len(positive_ucla_changes))
indices_negative = np.arange(len(negative_ucla_changes))

# Plotting bar graphs with patterns and different shades of grey for UCLA Loneliness
plt.figure(figsize=(12, 6))
bar_width = 0.35
plt.bar(
    indices_positive - bar_width / 2,
    positive_ucla_changes,
    bar_width,
    color='lightgrey',  # Light grey for positive group
    label='Positive Group (UCLA)',
)
plt.bar(
    indices_negative + bar_width / 2,
    negative_ucla_changes,
    bar_width,
    hatch='////',  # Denser pattern for negative group
    color='darkgrey',  # Dark grey for negative group
    label='Negative Group (UCLA)',
)

# Plotting bar graphs with patterns and different shades of grey for PHQ-9
plt.bar(
    indices_positive - bar_width / 2,
    positive_phq9_changes,
    bar_width,
    color='grey',  # Grey for positive group
    alpha=0.7,  # Adjust alpha for transparency
    label='Positive Group (PHQ-9)',
)
plt.bar(
    indices_negative + bar_width / 2,
    negative_phq9_changes,
    bar_width,
    hatch='////',  # Denser pattern for negative group
    color='black',  # Black for negative group
    alpha=0.7,  # Adjust alpha for transparency
    label='Negative Group (PHQ-9)',
)

plt.xlabel('Participant')
plt.ylabel('Change in Score')
plt.title('Change in Score: Perceived Barriers_Positive vs. Negative Group')
plt.legend()
plt.xticks(np.arange(0, max(len(positive_ucla_changes), len(negative_ucla_changes))))
plt.show()

# %%
from scipy.stats import mannwhitneyu

# 데이터
positive_ucla_changes = [-2, -10, 8, 5, -7, 4, -17, -5, 3, 3, -6, 4, -6, 4, -4, -8, -13, -3, -8]
negative_ucla_changes = [-4, 1, -3, -10, 2, -8, 2, -9]

positive_phq9_changes = [-10, 2, 4, -2, -4, -3, -2, 0, -3, -3, -2, -4, -3, -3, -5, -4, -8, 0, 1]
negative_phq9_changes = [0, -4, -6, 8, 2, -6, -8, -10]

# Mann-Whitney U Test for UCLA Loneliness changes
ucla_stat, ucla_p_value = mannwhitneyu(positive_ucla_changes, negative_ucla_changes)
print(f'UCLA Loneliness Mann-Whitney U Test p-value: {ucla_p_value}')

# Mann-Whitney U Test for PHQ-9 changes
phq9_stat, phq9_p_value = mannwhitneyu(positive_phq9_changes, negative_phq9_changes)
print(f'PHQ-9 Mann-Whitney U Test p-value: {phq9_p_value}')
# Out:
# UCLA Loneliness Mann-Whitney U Test p-value: 0.5946342315979949
# PHQ-9 Mann-Whitney U Test p-value: 0.4706129908371889

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'positive_ucla_changes' and 'negative_ucla_changes' are lists of individual change scores for UCLA Loneliness
# Assuming 'positive_phq9_changes' and 'negative_phq9_changes' are lists of individual change scores for PHQ-9
positive_ucla_changes = [-4,1,2,-17,-8,-3,-8,-10,-8,-2,8,5,-7,3,3,4,-4,2]
negative_ucla_changes = [-3,4,-5,-6,4,-13,-9,-10,-6]

positive_phq9_changes = [0,-4,2,-2,-4,0, 1,8,-6,-10,4,-2,-4,-3,-3,-4,-5,-8]
negative_phq9_changes = [-6, -3, 0, -2, -3, -8, -10, 2, -3]

# Generating indices for plotting
indices_positive = np.arange(len(positive_ucla_changes))
indices_negative = np.arange(len(negative_ucla_changes))

# Plotting bar graphs with patterns and different shades of grey for UCLA Loneliness
plt.figure(figsize=(12, 6))
bar_width = 0.35
plt.bar(
    indices_positive - bar_width / 2,
    positive_ucla_changes,
    bar_width,
    color='lightgrey',  # Light grey for positive group
    label='Positive Group (UCLA)',
)
plt.bar(
    indices_negative + bar_width / 2,
    negative_ucla_changes,
    bar_width,
    hatch='////',  # Denser pattern for negative group
    color='darkgrey',  # Dark grey for negative group
    label='Negative Group (UCLA)',
)

# Plotting bar graphs with patterns and different shades of grey for PHQ-9
plt.bar(
    indices_positive - bar_width / 2,
    positive_phq9_changes,
    bar_width,
    color='grey',  # Grey for positive group
    alpha=0.7,  # Adjust alpha for transparency
    label='Positive Group (PHQ-9)',
)
plt.bar(
    indices_negative + bar_width / 2,
    negative_phq9_changes,
    bar_width,
    hatch='////',  # Denser pattern for negative group
    color='black',  # Black for negative group
    alpha=0.7,  # Adjust alpha for transparency
    label='Negative Group (PHQ-9)',
)

plt.xlabel('Participant')
plt.ylabel('Change in Score')
plt.title('Change in Score: Help Seeking Behavior_Positive vs. Negative Group')
plt.legend()
plt.xticks(np.arange(0, max(len(positive_ucla_changes), len(negative_ucla_changes))))
plt.show()

# %%
from scipy.stats import mannwhitneyu

# 데이터
positive_ucla_changes = [-4,1,2,-17,-8,-3,-8,-10,-8,-2,8,5,-7,3,3,4,-4,2]
negative_ucla_changes = [-3,4,-5,-6,4,-13,-9,-10,-6]

positive_phq9_changes = [0,-4,2,-2,-4,0, 1,8,-6,-10,4,-2,-4,-3,-3,-4,-5,-8]
negative_phq9_changes = [-6, -3,0,-2,-3,-8,-10,2,-3]

# Mann-Whitney U Test for UCLA Loneliness changes
ucla_stat, ucla_p_value = mannwhitneyu(positive_ucla_changes, negative_ucla_changes)
print(f'UCLA Loneliness Mann-Whitney U Test p-value: {ucla_p_value}')

# Mann-Whitney U Test for PHQ-9 changes
phq9_stat, phq9_p_value = mannwhitneyu(positive_phq9_changes, negative_phq9_changes)
print(f'PHQ-9 Mann-Whitney U Test p-value: {phq9_p_value}')
# Out:
# UCLA Loneliness Mann-Whitney U Test p-value: 0.3402977701535178
# PHQ-9 Mann-Whitney U Test p-value: 0.6228678461566667

# %% [markdown]
# # **Revised figure accrording to Journal style**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for 3-a)
positive_ucla_changes_a = [-2, -5, 3, 3, -6, -3, -8, -10, -7, 4, -6, 4, -4, -8]
negative_ucla_changes_a = [1, -8, -4, -10, 2, -3, 2, -9, -3, -3, -3, -3, -3, -3]
positive_phq9_changes_a = [0, -3, -3, -2, 0, -2, -4, -3, -2, -4, -3, -3, -5, -4]
negative_phq9_changes_a = [-4, -6, 0, 8, 2, -6, -8, -10, -3, -3, -3, -3, -3, -3]

# Data for 3-b)
positive_ucla_changes_b = [-2, -10, 8, 5, -7, 4, -17, -5, 3, 3, -6, 4, -6, 4, -4, -8, -13, -3, -8]
negative_ucla_changes_b = [-4, 1, -3, -10, 2, -8, 2, -9]
positive_phq9_changes_b = [-10, 2, 4, -2, -4, -3, -2, 0, -3, -3, -2, -4, -3, -3, -5, -4, -8, 0, 1]
negative_phq9_changes_b = [0, -4, -6, 8, 2, -6, -8, -10]

# Data for 3-c)
positive_ucla_changes_c = [-4, 1, 2, -17, -8, -3, -8, -10, -8, -2, 8, 5, -7, 3, 3, 4, -4, 2]
negative_ucla_changes_c = [-3, 4, -5, -6, 4, -13, -9, -10, -6]
positive_phq9_changes_c = [0, -4, 2, -2, -4, 0, 1, 8, -6, -10, 4, -2, -4, -3, -3, -4, -5, -8]
negative_phq9_changes_c = [-6, -3, 0, -2, -3, -8, -10, 2, -3]

# Combined function to plot for each data set
def plot_changes(positive_ucla, negative_ucla, positive_phq9, negative_phq9, ax, subplot_title):
    indices_positive = np.arange(len(positive_ucla))
    indices_negative = np.arange(len(negative_ucla))

    bar_width = 0.35

    # UCLA Loneliness Scale Score
    ax.bar(
        indices_positive - bar_width / 2,
        positive_ucla,
        bar_width,
        color='lightgrey',
        label='Positive group: UCLA Loneliness Scale score',
    )
    ax.bar(
        indices_negative + bar_width / 2,
        negative_ucla,
        bar_width,
        hatch='////',
        color='darkgrey',
        label='Negative group: UCLA Loneliness Scale score',
    )

    # PHQ-9 Score
    ax.bar(
        indices_positive - bar_width / 2,
        positive_phq9,
        bar_width,
        color='grey',
        alpha=0.7,
        label='Positive group: PHQ-9',
    )
    ax.bar(
        indices_negative + bar_width / 2,
        negative_phq9,
        bar_width,
        hatch='////',
        color='black',
        alpha=0.7,
        label='Negative group: PHQ-9',
    )

    ax.set_xlabel('Participant', fontsize=8)  # x축 폰트 크기 줄이기
    ax.set_ylabel('Change in score', fontsize=10)
    ax.set_title(subplot_title, fontsize=9, fontweight='bold')  # 타이틀 폰트 크기 줄이기
    ax.set_xticks(np.arange(0, max(len(positive_ucla), len(negative_ucla))))
    ax.tick_params(axis='x', labelsize=6)  # x축 레이블 폰트 크기 줄이기
    ax.tick_params(axis='y', labelsize=8)

# Create a figure with subplots for 3-a, 3-b, and 3-c
fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # Three subplots in one row

# Plot for 3-a)
plot_changes(
    positive_ucla_changes_a, negative_ucla_changes_a,
    positive_phq9_changes_a, negative_phq9_changes_a,
    axs[0], "(a) Perceived benefits of action"
)

# Plot for 3-b)
plot_changes(
    positive_ucla_changes_b, negative_ucla_changes_b,
    positive_phq9_changes_b, negative_phq9_changes_b,
    axs[1], "(b) Perceived barriers of action"
)

# Plot for 3-c)
plot_changes(
    positive_ucla_changes_c, negative_ucla_changes_c,
    positive_phq9_changes_c, negative_phq9_changes_c,
    axs[2], "(c) Help-seeking behavior"
)

# Add a single legend at the bottom of the figure, with space
fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=2, fontsize=10)
plt.suptitle("Change in score", fontsize=14, fontweight='bold')

plt.tight_layout(rect=[0, 0.05, 1, 0.9])  # Adjust layout to make space for the legend at the bottom
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for 3-a)
positive_ucla_changes_a = [-2, -5, 3, 3, -6, -3, -8, -10, -7, 4, -6, 4, -4, -8]
negative_ucla_changes_a = [1, -8, -4, -10, 2, -3, 2, -9, -3, -3, -3, -3, -3, -3]
positive_phq9_changes_a = [0, -3, -3, -2, 0, -2, -4, -3, -2, -4, -3, -3, -5, -4]
negative_phq9_changes_a = [-4, -6, 0, 8, 2, -6, -8, -10, -3, -3, -3, -3, -3, -3]

# Data for 3-b)
positive_ucla_changes_b = [-2, -10, 8, 5, -7, 4, -17, -5, 3, 3, -6, 4, -6, 4, -4, -8, -13, -3, -8]
negative_ucla_changes_b = [-4, 1, -3, -10, 2, -8, 2, -9]
positive_phq9_changes_b = [-10, 2, 4, -2, -4, -3, -2, 0, -3, -3, -2, -4, -3, -3, -5, -4, -8, 0, 1]
negative_phq9_changes_b = [0, -4, -6, 8, 2, -6, -8, -10]

# Data for 3-c)
positive_ucla_changes_c = [-4, 1, 2, -17, -8, -3, -8, -10, -8, -2, 8, 5, -7, 3, 3, 4, -4, 2]
negative_ucla_changes_c = [-3, 4, -5, -6, 4, -13, -9, -10, -6]
positive_phq9_changes_c = [0, -4, 2, -2, -4, 0, 1, 8, -6, -10, 4, -2, -4, -3, -3, -4, -5, -8]
negative_phq9_changes_c = [-6, -3, 0, -2, -3, -8, -10, 2, -3]

# Combined function to plot for each data set
def plot_changes(positive_ucla, negative_ucla, positive_phq9, negative_phq9, ax, subplot_title):
    indices_positive = np.arange(len(positive_ucla))
    indices_negative = np.arange(len(negative_ucla))

    bar_width = 0.35

    # UCLA Loneliness Scale Score
    ax.bar(
        indices_positive - bar_width / 2,
        positive_ucla,
        bar_width,
        color='lightgrey',
        label='Positive group: UCLA Loneliness Scale score',
    )
    ax.bar(
        indices_negative + bar_width / 2,
        negative_ucla,
        bar_width,
        hatch='////',
        color='darkgrey',
        label='Negative group: UCLA Loneliness Scale score',
    )

    # PHQ-9 Score
    ax.bar(
        indices_positive - bar_width / 2,
        positive_phq9,
        bar_width,
        color='grey',
        alpha=0.7,
        label='Positive group: PHQ-9',
    )
    ax.bar(
        indices_negative + bar_width / 2,
        negative_phq9,
        bar_width,
        hatch='////',
        color='black',
        alpha=0.7,
        label='Negative group: PHQ-9',
    )

    ax.set_xlabel('Participant', fontsize=7)  # Reduce x-axis font size
    ax.set_ylabel('Change in score', fontsize=8)
    ax.set_title(subplot_title, fontsize=8, fontweight='bold')  # Reduce title font size
    ax.set_xticks(np.arange(0, max(len(positive_ucla), len(negative_ucla))))
    ax.tick_params(axis='x', labelsize=6)  # Reduce x-axis label font size
    ax.tick_params(axis='y', labelsize=7)

# Create a figure with subplots for 3-a, 3-b, and 3-c
fig, axs = plt.subplots(1, 3, figsize=(12, 4), dpi=300)  # Adjusted figsize and dpi for higher resolution

# Plot for 3-a)
plot_changes(
    positive_ucla_changes_a, negative_ucla_changes_a,
    positive_phq9_changes_a, negative_phq9_changes_a,
    axs[0], "(a) Perceived benefits of action"
)

# Plot for 3-b)
plot_changes(
    positive_ucla_changes_b, negative_ucla_changes_b,
    positive_phq9_changes_b, negative_phq9_changes_b,
    axs[1], "(b) Perceived barriers of action"
)

# Plot for 3-c)
plot_changes(
    positive_ucla_changes_c, negative_ucla_changes_c,
    positive_phq9_changes_c, negative_phq9_changes_c,
    axs[2], "(c) Help-seeking behavior"
)

# Add a single legend at the bottom of the figure, with space
fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.15), ncol=2, fontsize=8)
plt.suptitle("Change in score", fontsize=10, fontweight='bold')

plt.tight_layout(rect=[0, 0.05, 1, 0.9])  # Adjust layout to make space for the legend at the bottom
plt.subplots_adjust(hspace=0.4, wspace=0.4)  # Adjust the space between subplots
plt.savefig("combined_figure.png", dpi=300)  # Save the figure with high resolution
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for 3-a)
positive_ucla_changes_a = [-2, -5, 3, 3, -6, -3, -8, -10, -7, 4, -6, 4, -4, -8]
negative_ucla_changes_a = [1, -8, -4, -10, 2, -3, 2, -9, -3, -3, -3, -3, -3, -3]
positive_phq9_changes_a = [0, -3, -3, -2, 0, -2, -4, -3, -2, -4, -3, -3, -5, -4]
negative_phq9_changes_a = [-4, -6, 0, 8, 2, -6, -8, -10, -3, -3, -3, -3, -3, -3]

# Data for 3-b)
positive_ucla_changes_b = [-2, -10, 8, 5, -7, 4, -17, -5, 3, 3, -6, 4, -6, 4, -4, -8, -13, -3, -8]
negative_ucla_changes_b = [-4, 1, -3, -10, 2, -8, 2, -9]
positive_phq9_changes_b = [-10, 2, 4, -2, -4, -3, -2, 0, -3, -3, -2, -4, -3, -3, -5, -4, -8, 0, 1]
negative_phq9_changes_b = [0, -4, -6, 8, 2, -6, -8, -10]

# Data for 3-c)
positive_ucla_changes_c = [-4, 1, 2, -17, -8, -3, -8, -10, -8, -2, 8, 5, -7, 3, 3, 4, -4, 2]
negative_ucla_changes_c = [-3, 4, -5, -6, 4, -13, -9, -10, -6]
positive_phq9_changes_c = [0, -4, 2, -2, -4, 0, 1, 8, -6, -10, 4, -2, -4, -3, -3, -4, -5, -8]
negative_phq9_changes_c = [-6, -3, 0, -2, -3, -8, -10, 2, -3]

# Combined function to plot for each data set
def plot_changes(positive_ucla, negative_ucla, positive_phq9, negative_phq9, ax, subplot_title):
    indices_positive = np.arange(len(positive_ucla))
    indices_negative = np.arange(len(negative_ucla))

    bar_width = 0.35

    # UCLA Loneliness Scale Score
    ax.bar(
        indices_positive - bar_width / 2,
        positive_ucla,
        bar_width,
        color='lightgrey',
        label='Positive group: UCLA Loneliness Scale score',
    )
    ax.bar(
        indices_negative + bar_width / 2,
        negative_ucla,
        bar_width,
        hatch='////',
        color='darkgrey',
        label='Negative group: UCLA Loneliness Scale score',
    )

    # PHQ-9 Score
    ax.bar(
        indices_positive - bar_width / 2,
        positive_phq9,
        bar_width,
        color='grey',
        alpha=0.7,
        label='Positive group: PHQ-9',
    )
    ax.bar(
        indices_negative + bar_width / 2,
        negative_phq9,
        bar_width,
        hatch='////',
        color='black',
        alpha=0.7,
        label='Negative group: PHQ-9',
    )

    ax.set_xlabel('Participant', fontsize=7)  # Reduce x-axis font size
    ax.set_ylabel('Change in score', fontsize=8)
    ax.set_title(subplot_title, fontsize=8, fontweight='bold')  # Reduce title font size
    ax.set_xticks(np.arange(0, max(len(positive_ucla), len(negative_ucla))))
    ax.tick_params(axis='x', labelsize=6)  # Reduce x-axis label font size
    ax.tick_params(axis='y', labelsize=7)

# Create a figure with subplots for 3-a, 3-b, and 3-c
fig, axs = plt.subplots(3, 1, figsize=(8, 15), dpi=300)  # Adjusted figure size to increase height

# Plot for 3-a)
plot_changes(
    positive_ucla_changes_a, negative_ucla_changes_a,
    positive_phq9_changes_a, negative_phq9_changes_a,
    axs[0], "(a) Perceived benefits of action"
)

# Plot for 3-b)
plot_changes(
    positive_ucla_changes_b, negative_ucla_changes_b,
    positive_phq9_changes_b, negative_phq9_changes_b,
    axs[1], "(b) Perceived barriers of action"
)

# Plot for 3-c)
plot_changes(
    positive_ucla_changes_c, negative_ucla_changes_c,
    positive_phq9_changes_c, negative_phq9_changes_c,
    axs[2], "(c) Help-seeking behavior"
)

# Remove the legend and extend the height of the figure
plt.suptitle("Change in score", fontsize=10, fontweight='bold')

plt.tight_layout(rect=[0, 0.05, 1, 0.95])  # Adjust layout to avoid overlap
plt.subplots_adjust(hspace=0.4)  # Adjust the space between subplots
plt.savefig("combined_figure.png", dpi=300)  # Save the figure with high resolution
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for 3-a)
positive_ucla_changes_a = [-2, -5, 3, 3, -6, -3, -8, -10, -7, 4, -6, 4, -4, -8]
negative_ucla_changes_a = [1, -8, -4, -10, 2, -3, 2, -9, -3, -3, -3, -3, -3, -3]
positive_phq9_changes_a = [0, -3, -3, -2, 0, -2, -4, -3, -2, -4, -3, -3, -5, -4]
negative_phq9_changes_a = [-4, -6, 0, 8, 2, -6, -8, -10, -3, -3, -3, -3, -3, -3]

# Data for 3-b)
positive_ucla_changes_b = [-2, -10, 8, 5, -7, 4, -17, -5, 3, 3, -6, 4, -6, 4, -4, -8, -13, -3, -8]
negative_ucla_changes_b = [-4, 1, -3, -10, 2, -8, 2, -9]
positive_phq9_changes_b = [-10, 2, 4, -2, -4, -3, -2, 0, -3, -3, -2, -4, -3, -3, -5, -4, -8, 0, 1]
negative_phq9_changes_b = [0, -4, -6, 8, 2, -6, -8, -10]

# Data for 3-c)
positive_ucla_changes_c = [-4, 1, 2, -17, -8, -3, -8, -10, -8, -2, 8, 5, -7, 3, 3, 4, -4, 2]
negative_ucla_changes_c = [-3, 4, -5, -6, 4, -13, -9, -10, -6]
positive_phq9_changes_c = [0, -4, 2, -2, -4, 0, 1, 8, -6, -10, 4, -2, -4, -3, -3, -4, -5, -8]
negative_phq9_changes_c = [-6, -3, 0, -2, -3, -8, -10, 2, -3]

# Combined function to plot for each data set
def plot_changes(positive_ucla, negative_ucla, positive_phq9, negative_phq9, ax, subplot_title):
    indices_positive = np.arange(len(positive_ucla))
    indices_negative = np.arange(len(negative_ucla))

    bar_width = 0.35

    # UCLA Loneliness Scale Score
    ax.bar(
        indices_positive - bar_width / 2,
        positive_ucla,
        bar_width,
        color='lightgrey',
        label='Positive group: UCLA Loneliness Scale score',
    )
    ax.bar(
        indices_negative + bar_width / 2,
        negative_ucla,
        bar_width,
        hatch='////',
        color='darkgrey',
        label='Negative group: UCLA Loneliness Scale score',
    )

    # PHQ-9 Score
    ax.bar(
        indices_positive - bar_width / 2,
        positive_phq9,
        bar_width,
        color='grey',
        alpha=0.7,
        label='Positive group: PHQ-9',
    )
    ax.bar(
        indices_negative + bar_width / 2,
        negative_phq9,
        bar_width,
        hatch='////',
        color='black',
        alpha=0.7,
        label='Negative group: PHQ-9',
    )

    ax.set_xlabel('Participant', fontsize=7)
    ax.set_ylabel('Change in score', fontsize=8)
    ax.set_title(subplot_title, fontsize=8, fontweight='bold')
    ax.set_xticks(np.arange(0, max(len(positive_ucla), len(negative_ucla))))
    ax.tick_params(axis='x', labelsize=6)
    ax.tick_params(axis='y', labelsize=7)

# Create a figure with subplots for 3-a, 3-b, and 3-c
fig, axs = plt.subplots(1, 3, figsize=(15, 5), dpi=300)  # Three subplots in one row

# Plot for 3-a)
plot_changes(
    positive_ucla_changes_a, negative_ucla_changes_a,
    positive_phq9_changes_a, negative_phq9_changes_a,
    axs[0], "(a) Perceived benefits of action"
)

# Plot for 3-b)
plot_changes(
    positive_ucla_changes_b, negative_ucla_changes_b,
    positive_phq9_changes_b, negative_phq9_changes_b,
    axs[1], "(b) Perceived barriers of action"
)

# Plot for 3-c)
plot_changes(
    positive_ucla_changes_c, negative_ucla_changes_c,
    positive_phq9_changes_c, negative_phq9_changes_c,
    axs[2], "(c) Help-seeking behavior"
)

# 중앙에 제목 추가
plt.suptitle("Change in score", fontsize=10, fontweight='bold')

plt.tight_layout(rect=[0, 0.05, 1, 0.95])  # Adjust layout to avoid overlap
plt.subplots_adjust(hspace=0.4)  # Adjust the space between subplots
plt.savefig("combined_figure.png", dpi=300)  # Save the figure with high resolution
plt.show()
